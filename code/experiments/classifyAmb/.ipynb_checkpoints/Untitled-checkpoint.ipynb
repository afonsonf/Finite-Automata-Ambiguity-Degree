# %%
import shelve
import os

import cPickle as pickle

from FAdo.fa import *
from FAdo.reex import *
from FAdo.fio import *

import ambiguityTest
# import degreeOfAmbiguity
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-c97a7481f05c> in <module>()
#       9
#      10 import ambiguityTest
# ---> 11 import degreeOfAmbiguity
#
# ImportError: No module named degreeOfAmbiguity

# %%
db = shelve.open('data/pd_2_20')
s = db["{}".format(50)]["nfa"]
nfa.display()
db.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-2dfa06490085> in <module>()
#       1 db = shelve.open('data/pd_2_20')
#       2 s = db["{}".format(50)]["nfa"]
# ----> 3 nfa.display()
#       4 db.close()
#
# NameError: global name 'nfa' is not defined

# %%
# Out:
# False
# False
# False

# %%
# Out:
# False
# False
# True

# %%
# Out:
# True
# True
# True
