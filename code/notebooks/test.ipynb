# %%
>>> from FAdo.fa import *
>>> from FAdo.reex import *
>>> from FAdo.fio import *

# %%
r1 = str2regexp("a*aba*")
r2 = str2regexp("a*b*")

# %%
m1 = r1.toNFA()
m1.display()

# %%
m2 = r2.toNFA()
m2.display()

# %%
m = m1.__and__(m2)
m.display()

# %%
m = m1.__and__(m1)
m.display()
