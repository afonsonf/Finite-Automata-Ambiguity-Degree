# %%
>>> from FAdo.fa import *
>>> from FAdo.reex import *
>>> from FAdo.fio import *

# %%
m = NFA()
m.addState()
m.addState()
m.addInitial(0)
m.addFinal(1)
m.addTransition(0,'b',0)
m.addTransition(0,'b',1)
m.addTransition(1,'a',1)
m.addTransition(1,'b',1)
m.display()

# %%
conj = m.__and__(m).trim().display()
